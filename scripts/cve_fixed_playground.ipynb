# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.4-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached numpy-2.3.4-cp312-cp312-win_amd64.whl (12.8 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/cvefixed_c_cpp_method.csv')

# %%
print(df.shape)
print(df.columns)
# Out:
# (19576, 13)
# Index(['Unnamed: 0', 'cve_id', 'filename', 'old_path', 'new_path', 'name',
#        'code', 'nloc', 'before_change', 'cwe_id', 'cwe_name', 'repo_url',
#        'vul'],
#       dtype='object')

# %%
# Pull together the first couple of vul pairs (vul = True | False) for the same 'cve_id' and 'cwe_id'
# (19576, 13)
# Index(['Unnamed: 0', 'cve_id', 'filename', 'old_path', 'new_path', 'name',
#        'code', 'nloc', 'before_change', 'cwe_id', 'cwe_name', 'repo_url',
#        'vul'],
#       dtype='object')

# iterate through rows and print cve_id, cwe_id, vul
for index, row in df.iterrows():
    print(f"cve_id: {row['cve_id']}, cwe_id: {row['cwe_id']}, vul: {row['vul']}, filename: {row['filename']}, nloc: {row['nloc']}, 'before_change': {row['before_change']}")
    if index >= 10:  # limit output for brevity
        break
# Out:
# cve_id: CVE-1999-0199, cwe_id: CWE-252, vul: False, filename: dl-load.c, nloc: 29.0, 'before_change': False
# cve_id: CVE-1999-0199, cwe_id: CWE-252, vul: True, filename: dl-load.c, nloc: 22.0, 'before_change': True
# cve_id: CVE-1999-0199, cwe_id: CWE-252, vul: True, filename: dl-load.c, nloc: 51.0, 'before_change': True
# cve_id: CVE-1999-0199, cwe_id: CWE-252, vul: False, filename: dl-load.c, nloc: 57.0, 'before_change': False
# cve_id: CVE-1999-0199, cwe_id: CWE-252, vul: True, filename: dl-load.c, nloc: 14.0, 'before_change': True
# cve_id: CVE-1999-0199, cwe_id: CWE-252, vul: False, filename: dl-load.c, nloc: 14.0, 'before_change': False
# cve_id: CVE-1999-0199, cwe_id: CWE-252, vul: True, filename: syslog.c, nloc: 85.0, 'before_change': True
# cve_id: CVE-1999-0199, cwe_id: CWE-252, vul: False, filename: syslog.c, nloc: 88.0, 'before_change': False
# cve_id: CVE-1999-0199, cwe_id: CWE-252, vul: False, filename: regex.c, nloc: 13.0, 'before_change': False
# ...
